# %% [markdown]
# # BESTEST Case 660 — VDI 6007 validation

# %%
from pathlib import Path
import sys
cwd = Path.cwd().resolve()
root = next(p for p in (cwd, *cwd.parents) if (p / 'validation/bestest_vdi_reporting.py').is_file())
sys.path.insert(0, str(root / 'validation'))
from bestest_vdi_reporting import (case_definition, resolved_input_mapping, static_checks, annual_validation, parent_response)
CASE = "660"

# %% [markdown]
# ## Case definition and provenance

# %%
case_definition(CASE)
# Out:
#   case_id paired_case parent_base      physical_change implementation_class  \
# 0     660         NaN         600  low-e argon glazing                    C
#
#                    iso_notebook
# 0  01f_case660_validation.ipynb

# %% [markdown]
# ## Resolved VDI input mapping

# %%
resolved_input_mapping(CASE)
# Out:
#                           VDI input  \
# 0               opaque construction
# 1  wall / roof / floor U [W/(m2 K)]
# 2                     window system
# 3                      window U / g
# 4         window orientation / area
# 5                    shading factor
# 6        thermostat / airflow delta
#
#                                       resolved value  \
# 0                                                600
# 1                                0.53 / 0.33 / 0.038
# 2                                            case660
# 3                                        1.19 / 0.44
# 4                               south windows: 12 m2
# 5                                                  1
# 6  window U-value: 1.45 W/(m2 K); window solar g-...
#
#                                provenance
# 0       ashrae140_case_constructions.json
# 1          prescribed transmission inputs
# 2       ashrae140_case_constructions.json
# 3  ASHRAE 140-2023 Informative Table 7-18
# ...

# %% [markdown]
# ## Static validation checks

# %%
static_checks(CASE)
# Out:
#                                        check  pass
# 0          authoritative material convention  True
# 1           three opaque assemblies resolved  True
# 2                       window area is 12 m2  True
# 3  positive film-excluded glazing resistance  True
# 4                    finite layer properties  True

# %% [markdown]
# ## Annual heating and cooling against benchmark bounds

# %%
annual_validation(CASE)
# Out:
#   configuration  heating_MWh  cooling_MWh heating_in_range cooling_in_range  \
# 0      F36-like     3.726306     3.445704             True             True
# 1      F52-like     3.724758     3.456600             True             True
#
#   both_in_range  D_MWh_norm  maximum_balance_residual_W
# 0          True         0.0                4.547474e-13
# 1          True         0.0                4.547474e-13

# %% [markdown]
# ## Parent-relative interpretation

# %%
parent_response(CASE)
# Out:
#   configuration parent  heating_delta_MWh  cooling_delta_MWh  \
# 0      F36-like    600          -1.097111          -2.233098
# 1      F52-like    600          -1.091312          -2.291800
#
#                                       interpretation
# 0  Heating decreases; cooling decreases versus Ca...
# 1  Heating decreases; cooling decreases versus Ca...
