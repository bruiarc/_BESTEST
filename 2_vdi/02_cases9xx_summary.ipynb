# %% [markdown]
# # BESTEST 9XX — VDI 6007 summary

# %%
from pathlib import Path
import sys
cwd = Path.cwd().resolve()
root = next(p for p in (cwd, *cwd.parents) if (p / 'validation/bestest_vdi_reporting.py').is_file())
sys.path.insert(0, str(root / 'validation'))
from bestest_vdi_reporting import family_summary, combined_summary, unresolved_benchmark_issues

# %% [markdown]
# ## Annual benchmark and parent-relative response

# %%
family_summary('9xx')
# Out:
#    case configuration  heating_MWh  cooling_MWh heating_in_range  \
# 22  900      F36-like     2.272013     2.544784             True
# 23  900      F52-like     2.259676     2.596246             True
# 24  910      F36-like     2.713501     1.963618              NaN
# 25  910      F52-like     2.697452     1.998029              NaN
# 26  920      F36-like     3.768617     2.685657             True
# 27  920      F52-like     3.749431     2.720264             True
# 28  930      F36-like     4.269574     1.967100             True
# 29  930      F52-like     4.252329     1.991647             True
# 30  940      F36-like     1.456590     2.514827             True
# 31  940      F52-like     1.429949     2.561644             True
# 32  950      F36-like     0.000000     0.901369             True
# 33  950      F52-like     0.000000     0.944067             True
# 34  980      F36-like     0.611819     3.796456             True
# ...

# %% [markdown]
# ## Unresolved benchmark-data issues

# %%
unresolved_benchmark_issues()
# Out:
#    case  lower_heating  upper_heating  lower_cooling  upper_cooling  \
# 24  910           1.56            2.3            2.0           0.86
#
#                                                 issue
# 24  invalid/reversed benchmark bounds; pass/fail w...
