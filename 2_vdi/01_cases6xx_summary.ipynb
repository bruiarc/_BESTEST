# %% [markdown]
# # BESTEST 6XX — VDI 6007 summary

# %%
from doc.bestest_vdi_reporting import family_summary, combined_summary, unresolved_benchmark_issues

# %% [markdown]
# ## Annual benchmark and parent-relative response

# %%
family_summary('6xx')
# Out:
#    case configuration  heating_MWh  cooling_MWh heating_in_range  \
# 0   600      F36-like     4.823417     5.678802             True
# 1   600      F52-like     4.816070     5.748399             True
# 2   610      F36-like     4.955557     4.574798             True
# 3   610      F52-like     4.948545     4.631267             True
# 4   620      F36-like     5.007976     4.075384             True
# 5   620      F52-like     4.996804     4.119281             True
# 6   630      F36-like     5.254494     3.072728             True
# 7   630      F52-like     5.243362     3.103070             True
# 8   640      F36-like     2.778307     5.493815             True
# 9   640      F52-like     2.767620     5.559387             True
# 10  650      F36-like     0.000000     4.953261             True
# 11  650      F52-like     0.000000     5.021564             True
# 12  660      F36-like     3.726306     3.445704             True
# ...

# %% [markdown]
# ## Unresolved benchmark-data issues

# %%
unresolved_benchmark_issues()
# Out:
#    case  lower_heating  upper_heating  lower_cooling  upper_cooling  \
# 24  910           1.56            2.3            2.0           0.86
#
#                                                 issue
# 24  invalid/reversed benchmark bounds; pass/fail w...
